# %%
import pandas as pd

# %%
data = pd.read_csv('data/CombinedData.csv')

# %%
data
# Out:
#                                            QuestionText   QType Answer  \
# 0     Will advanced LIGO announce discovery of gravi...  binary     no
# 1     Will SpaceX successfully land a Falcon 9 rocke...  binary     no
# 2     Will we confirm evidence for megastructures or...  binary     no
# 3     Will Lockheed Martin and Skunkworks announce a...  binary     no
# 4     The FAA to soon open the door to commercial us...  binary     no
# ...                                                 ...     ...    ...
# 7921  Between 3 October 2019 and 29 November 2019, w...  binary     no
# 7922  Will the PITF Worldwide Atrocities Dataset rec...  binary    yes
# 7923  Will ACLED record any civilian fatalities in R...  binary    yes
# 7924  Will ACLED record any civilian fatalities in S...  binary    yes
# 7925  Will there be a significant day-over-day incre...  binary    yes
#
#      AnswerChoices  Year                                               Tags  \
# ...

# %%
data['Tags'][0]
# Out:
# "['research impact', 'scientific discoveries', 'technological advances', 'phys sci  astro and cosmo', 'phys sci  generalrelativity and quantumcosmology', 'tech  general']"

# %%
import ast
import numpy as np
tags = []
for i in range(len(data['Tags'])):
    if 
    tags.extend(ast.literal_eval(data['Tags'][i]))
tags = [ast.literal_eval(data['Tags'][i]) if data['Tags'][i] is not np.nan else None for i in range(len(data['Tags']))]

# %%
print(tags)
# Out:
# [['research impact', 'scientific discoveries', 'technological advances', 'phys sci  astro and cosmo', 'phys sci  generalrelativity and quantumcosmology', 'tech  general'], ['app success', 'technological advances', 'phys sci  astro and cosmo', 'phys sci  general', 'tech  automotive', 'tech  general'], ['scientific discoveries', 'phys sci  astro and cosmo', 'phys sci  general'], ['research impact', 'technological advances', 'phys sci  chemistry', 'phys sci  condensedmatter and materials', 'phys sci  nuclear', 'tech  general'], ['research impact', 'technological advances', 'computing  ai', 'tech  consumerelectronics', 'tech  general', 'tech  robots'], ['bio  genetics', 'app success', 'technological advances', 'tech  biotech'], ['research impact', 'math  pure'], ['comp sci  ai and machinelearning', 'computing  ai'], [], [], ['research impact', 'technological advances', 'comp sci  ai and machinelearning', 'computing  ai', 'tech  automotive', 'tech  consumerelectronics', 'tech  robots'], [
# ...
